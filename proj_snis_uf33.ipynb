# %%
import pandas as pd
import plotly

# %% [markdown]
# # Importar dataset SNIS e abrir como um Pandas DataFrame

# %%
# Abrir, Ler e atribuir a uma variável os dados .csv do snis de 2021
df_snis = pd.read_csv('snis_municipios.csv', sep=';', decimal=',', thousands='.', encoding='utf-16-le', index_col=False)

# Exibir o dataframe
df_snis.head()
# Out:
#   Código do IBGE Código do Município       Município Estado Ano de Referência  \
# 0        3300100              330010  Angra dos Reis     RJ              2021
# 1        3300100              330010  Angra dos Reis     RJ              2020
# 2        3300100              330010  Angra dos Reis     RJ              2019
# 3            NaN              330010  Angra dos Reis     RJ              2018
# 4            NaN              330010  Angra dos Reis     RJ              2017
#
#                                          Prestadores  \
# 0  [33045500] Companhia Estadual de Águas e Esgot...
# 1  [33045500] Companhia Estadual de Águas e Esgot...
# 2  [33045500] Companhia Estadual de Águas e Esgot...
# 3  [33001011] Serviço Autônomo de Água e Esgoto d...
# 4  [33001011] Serviço Autônomo de Água e Esgoto d...
#
#                               Serviços  \
# 0  Água e Esgoto | Água | Res. Sólidos
# 1  Água e Esgoto | Água | Res. Sólidos
# 2  Água e Esgoto | Água | Res. Sólidos
# 3  Água e Esgoto | Água | Res. Sólidos
# 4  Água e Esgoto | Água | Res. Sólidos
#
#                                    Natureza Jurídica  \
# 0  Autarquia | Sociedade de economia mista com ad...
# 1  Autarquia | Sociedade de economia mista com ad...
# 2  Autarquia | Sociedade de economia mista com ad...
# 3                                                NaN
# 4                                                NaN
#
#    G06A - População urbana residente do(s) município(s) com abastecimento de água  \
# 0                                           202458.0
# 1                                           199446.0
# 2                                           196306.0
# 3                                           193052.0
# 4                                           187477.0
#
#    G06B - População urbana residente do(s) município(s) com esgotamento sanitário  \
# 0                                           202458.0
# 1                                           199446.0
# 2                                           196306.0
# 3                                           193052.0
# 4                                           187477.0
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    IN043_RS - Custo unitário médio do serviço de varrição (prefeitura + empresas contratadas)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    IN044_RS - Produtividade média dos varredores (prefeitura + empresas contratadas)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    IN045_RS - Taxa de varredores em relação à população urbana  \
# 0                                                NaN
# 1                                               0.88
# 2                                                NaN
# 3                                                NaN
# 4                                               0.93
#
#    IN046_RS - Incidência do custo do serviço de varrição no custo total com manejo de rsu  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                              30.98
#
#    IN047_RS - Incidência de varredores no total de empregados no manejo de rsu  \
# 0                                                NaN
# 1                                              40.42
# 2                                                NaN
# 3                                                NaN
# 4                                              40.42
#
#    IN048_RS - Extensão total anual varrida per capita  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    IN051_RS - Taxa de capinadores em relação à população urbana  \
# 0                                                NaN
# 1                                               0.25
# 2                                                NaN
# 3                                                NaN
# 4                                               0.27
#
#    IN052_RS - Incidência de capinadores no total empregados no manejo de rsu  \
# 0                                                NaN
# 1                                              11.55
# 2                                                NaN
# 3                                                NaN
# 4                                              11.55
#
#   IN053_RS - Taxa de material recolhido pela coleta seletiva (exceto mat.  orgânica) em relação à quantidade total coletada de resíduos sól.  domésticos  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                              11.91
#
#   IN054_RS - Massa per capita de materiais recicláveis recolhidos via coleta seletiva
# 0                                              27.65
# 1                                               0.85
# 2                                               0.96
# 3                                              82.47
# 4                                              31.31
#
# [5 rows x 658 columns]

# %% [markdown]
# # Data Cleaning
#
# ## Processo de Renomear as colunas do DataFrame
#
# ### Inicialmente separamos as colunas de código do SNIS das Colunas que não são de código para tratá-las de forma diferente.
#
# **Atenção:** há 2 formas de iterar nas colunas do dataframe e retornar listas com os nomes das colunas, as duas formas estão descritas abaixo, são elas: List Comprehension e Laço For

# %%
# FORMAS DE FAZER LISTAS UTILIZANDO 'list comprehension'

# Construir uma lista "colunas_sem_codigo" iterando nas colunas até 8 do "df"
colunas_sem_codigo = [coluna for coluna in df_snis.columns[:8]]
# Construir uma lista "colunas_com_codigo" iterando nas colunas do "df" que não estão na lista "colunas_sem_codigo"
colunas_com_codigo = [coluna for coluna in df_snis.columns if coluna not in colunas_sem_codigo]

# OUTRA FORMA DE FAZER LISTAS UTILIZANDO Laço For

'''# Cria uma lista com o nome das colunas
# Itera nas colunas até 8 e adiciona/append a coluna na lista
colunas_sem_codigo = []
for coluna in df.columns[:8]:
    colunas_sem_codigo.append(coluna)

# Cria uma lista com o nome das colunas
# Itera nas colunas que não fazem parte da lista "colunas_sem_codigo"
# adiciona/append a coluna na lista "coluna_com_codigo"
colunas_com_codigo = []
for col in df.columns:
    if col not in colunas_sem_codigo:
        colunas_com_codigo.append(col)'''
# Out:
# '# Cria uma lista com o nome das colunas\n# Itera nas colunas até 8 e adiciona/append a coluna na lista\ncolunas_sem_codigo = []\nfor coluna in df.columns[:8]:\n    colunas_sem_codigo.append(coluna)\n\n# Cria uma lista com o nome das colunas\n# Itera nas colunas que não fazem parte da lista "colunas_sem_codigo"\n# adiciona/append a coluna na lista "coluna_com_codigo"\ncolunas_com_codigo = []\nfor col in df.columns:\n    if col not in colunas_sem_codigo:\n        colunas_com_codigo.append(col)'

# %%
# Limpar o nome textual e deixar somente os códigos das informações e indicadores do SNIS no dataframe "colunas"
colunas_com_codigo = [x[:x.find('-') -1 ] for x in colunas_com_codigo]

# Reunir as duas listas de colunas, com e sem código, em uma lista "colunas"
colunas = colunas_sem_codigo + colunas_com_codigo

# Exibir as colunas
colunas
# Out:
# ['Código do IBGE',
#  'Código do Município',
#  'Município',
#  'Estado',
#  'Ano de Referência',
#  'Prestadores',
#  'Serviços',
#  'Natureza Jurídica',
#  'G06A',
#  'G06B',
#  'G12A',
#  'G12B',
#  'GE008',
#  'GE009',
#  'GE010',
#  'GE011',
#  'POP_TOT',
#  'POP_URB',
#  'GE201',
#  'GE202',
#  'AG001',
#  'AG002',
#  'AG003',
#  'AG004',
#  'AG005',
#  'AG006',
#  'AG007',
#  'AG008',
#  'AG010',
#  'AG011',
#  'AG012',
#  'AG013',
#  'AG014',
#  'AG015',
#  'AG017',
#  'AG018',
#  'AG019',
#  'AG020',
#  'AG021',
#  'AG022',
#  'AG024',
#  'AG026',
#  'AG027',
#  'AG028',
#  'ES001',
#  'ES002',
#  'ES003',
#  'ES004',
#  'ES005',
#  'ES006',
#  'ES007',
#  'ES008',
#  'ES009',
#  'ES012',
#  'ES013',
#  'ES014',
#  'ES015',
#  'ES026',
#  'ES028',
#  'FN001',
#  'FN002',
#  'FN003',
#  'FN004',
#  'FN005',
#  'FN006',
#  'FN007',
#  'FN008',
#  'FN010',
#  'FN011',
#  'FN013',
#  'FN014',
#  'FN015',
#  'FN016',
#  'FN017',
#  'FN018',
#  'FN019',
#  'FN020',
#  'FN021',
#  'FN022',
#  'FN023',
#  'FN024',
#  'FN025',
#  'FN026',
#  'FN027',
#  'FN028',
#  'FN030',
#  'FN031',
#  'FN032',
#  'FN033',
#  'FN034',
#  'FN035',
#  'FN036',
#  'FN037',
#  'FN038',
#  'FN039',
#  'FN041',
#  'FN042',
#  'FN043',
#  'FN044',
#  'FN045',
#  'FN046',
#  'FN047',
#  'FN048',
#  'FN051',
#  'FN052',
#  'FN053',
#  'FN054',
#  'FN055',
#  'FN056',
#  'FN057',
#  'FN058',
#  'QD001',
#  'QD002',
#  'QD003',
#  'QD004',
#  'QD006',
#  'QD007',
#  'QD008',
#  'QD009',
#  'QD011',
#  'QD012',
#  'QD015',
#  'QD016',
#  'QD017',
#  'QD019',
#  'QD020',
#  'QD021',
#  'QD022',
#  'QD023',
#  'QD024',
#  'QD025',
#  'QD026',
#  'QD027',
#  'QD028',
#  'QD029',
#  'CA001',
#  'CA002',
#  'CA003',
#  'CA004',
#  'CA005',
#  'CA006',
#  'CA007',
#  'CA008',
#  'CA009',
#  'CC010',
#  'CC011',
#  'CC012',
#  'CC013',
#  'CC014',
#  'CC015',
#  'CC016',
#  'CC017',
#  'CC018',
#  'CC019',
#  'CC020',
#  'CO001',
#  'CO002',
#  'CO003',
#  'CO004',
#  'CO008',
#  'CO012',
#  'CO013',
#  'CO014',
#  'CO019',
#  'CO020',
#  'CO021',
#  'CO022',
#  'CO050',
#  'CO051',
#  'CO052',
#  'CO053',
#  'CO054',
#  'CO055',
#  'CO056',
#  'CO057',
#  'CO058',
#  'CO059',
#  'CO060',
#  'CO061',
#  'CO062',
#  'CO063',
#  'CO064',
#  'CO065',
#  'CO066',
#  'CO067',
#  'CO068',
#  'CO069',
#  'CO070',
#  'CO071',
#  'CO072',
#  'CO073',
#  'CO074',
#  'CO075',
#  'CO076',
#  'CO077',
#  'CO078',
#  'CO079',
#  'CO080',
#  'CO081',
#  'CO082',
#  'CO083',
#  'CO084',
#  'CO085',
#  'CO086',
#  'CO087',
#  'CO088',
#  'CO089',
#  'CO090',
#  'CO091',
#  'CO092',
#  'CO093',
#  'CO094',
#  'CO095',
#  'CO096',
#  'CO097',
#  'CO098',
#  'CO099',
#  'CO100',
#  'CO101',
#  'CO102',
#  'CO103',
#  'CO104',
#  'CO105',
#  'CO106',
#  'CO107',
#  'CO108',
#  'CO109',
#  'CO110',
#  'CO111',
#  'CO112',
#  'CO113',
#  'CO114',
#  'CO115',
#  'CO116',
#  'CO117',
#  'CO118',
#  'CO119',
#  'CO120',
#  'CO121',
#  'CO122',
#  'CO123',
#  'CO124',
#  'CO125',
#  'CO126',
#  'CO127',
#  'CO128',
#  'CO129',
#  'CO130',
#  'CO131',
#  'CO133',
#  'CO134',
#  'CO135',
#  'CO136',
#  'CO137',
#  'CO138',
#  'CO139',
#  'CO140',
#  'CO141',
#  'CO142',
#  'CO143',
#  'CO144',
#  'CO145',
#  'CO146',
#  'CO147',
#  'CO148',
#  'CO149',
#  'CO150',
#  'CO151',
#  'CO152',
#  'CO154',
#  'CO155',
#  'CO156',
#  'CO157',
#  'CO158',
#  'CO159',
#  'CO160',
#  'CO161',
#  'CO162',
#  'CO163',
#  'CO164',
#  'CO165',
#  'CO170',
#  'CO171',
#  'CO172',
#  'CO173',
#  'CO174',
#  'CO175',
#  'CP001',
#  'CP002',
#  'CP003',
#  'CP004',
#  'CS001',
#  'CS002',
#  'CS009',
#  'CS010',
#  'CS011',
#  'CS012',
#  'CS013',
#  'CS014',
#  'CS022',
#  'CS023',
#  'CS024',
#  'CS025',
#  'CS026',
#  'CS027',
#  'CS028',
#  'CS029',
#  'CS030',
#  'CS031',
#  'CS032',
#  'CS033',
#  'CS034',
#  'CS035',
#  'CS036',
#  'CS037',
#  'CS038',
#  'CS039',
#  'CS040',
#  'CS041',
#  'CS042',
#  'CS043',
#  'CS044',
#  'CS045',
#  'CS046',
#  'CS047',
#  'CS048',
#  'CS049',
#  'CS050',
#  'CS053',
#  'CS054',
#  'CS055',
#  'CS056',
#  'CS057',
#  'CS058',
#  'CS059',
#  'CS060',
#  'FN201',
#  'FN202',
#  'FN203',
#  'FN204',
#  'FN205',
#  'FN206',
#  'FN207',
#  'FN208',
#  'FN209',
#  'FN210',
#  'FN211',
#  'FN212',
#  'FN213',
#  'FN214',
#  'FN215',
#  'FN216',
#  'FN217',
#  'FN218',
#  'FN219',
#  'FN220',
#  'FN221',
#  'FN222',
#  'FN223',
#  'FN224',
#  'FN225',
#  'FN226',
#  'FN227',
#  'OS001',
#  'OS003',
#  'OS004',
#  'OS005',
#  'OS006',
#  'OS007',
#  'OS008',
#  'OS009',
#  'OS010',
#  'OS011',
#  'OS012',
#  'OS014',
#  'OS015',
#  'OS016',
#  'OS017',
#  'OS018',
#  'OS019',
#  'OS020',
#  'OS021',
#  'OS022',
#  'OS023',
#  'OS025',
#  'OS026',
#  'OS027',
#  'OS028',
#  'OS029',
#  'OS030',
#  'OS031',
#  'OS032',
#  'OS033',
#  'OS040',
#  'OS041',
#  'OS042',
#  'OS043',
#  'OS044',
#  'OS045',
#  'OS046',
#  'OS047',
#  'OS048',
#  'OS049',
#  'OS050',
#  'OS051',
#  'OS052',
#  'OS053',
#  'PO001',
#  'PO002',
#  'PO004',
#  'PO005',
#  'PO006',
#  'PO007',
#  'PO008',
#  'PO009',
#  'PO010',
#  'PO011',
#  'PO012',
#  'PO013',
#  'PO014',
#  'PO015',
#  'PO016',
#  'PO017',
#  'PO018',
#  'PO019',
#  'PO020',
#  'PO021',
#  'PO022',
#  'PO023',
#  'PO024',
#  'PO025',
#  'PO026',
#  'PO027',
#  'PO028',
#  'PO029',
#  'PO031',
#  'PO033',
#  'PO034',
#  'PO035',
#  'PO036',
#  'PO037',
#  'PO038',
#  'PO039',
#  'PO040',
#  'PO041',
#  'PO042',
#  'PO043',
#  'PO044',
#  'PO045',
#  'PO046',
#  'PO047',
#  'PO048',
#  'PO049',
#  'PO050',
#  'PO051',
#  'RS003',
#  'RS004',
#  'RS008',
#  'RS009',
#  'RS020',
#  'RS021',
#  'RS022',
#  'RS023',
#  'RS024',
#  'RS025',
#  'RS026',
#  'RS027',
#  'RS028',
#  'RS030',
#  'RS031',
#  'RS034',
#  'RS036',
#  'RS038',
#  'RS039',
#  'RS040',
#  'RS041',
#  'RS042',
#  'RS043',
#  'RS044',
#  'RS045',
#  'RS046',
#  'TB001',
#  'TB002',
#  'TB003',
#  'TB004',
#  'TB005',
#  'TB006',
#  'TB007',
#  'TB008',
#  'TB009',
#  'TB010',
#  'TB011',
#  'TB012',
#  'TB013',
#  'TB014',
#  'TB015',
#  'TB016',
#  'TB017',
#  'TB018',
#  'TB019',
#  'TB020',
#  'TB021',
#  'TB022',
#  'TB023',
#  'TB024',
#  'TB025',
#  'TB026',
#  'TB027',
#  'TB028',
#  'TB029',
#  'TB030',
#  'TB031',
#  'TB032',
#  'TB033',
#  'TB034',
#  'TB035',
#  'VA001',
#  'VA002',
#  'VA003',
#  'VA004',
#  'VA010',
#  'VA011',
#  'VA012',
#  'VA016',
#  'VA020',
#  'VA021',
#  'VA030',
#  'VA031',
#  'VA032',
#  'VA033',
#  'VA034',
#  'VA035',
#  'VA036',
#  'VA038',
#  'VA039',
#  'IN001_AE',
#  'IN002_AE',
#  'IN003_AE',
#  'IN004_AE',
#  'IN005_AE',
#  'IN006_AE',
#  'IN007_AE',
#  'IN008_AE',
#  'IN009_AE',
#  'IN010_AE',
#  'IN011_AE',
#  'IN012_AE',
#  'IN013_AE',
#  'IN014_AE',
#  'IN015_AE',
#  'IN016_AE',
#  'IN017_AE',
#  'IN018_AE',
#  'IN019_AE',
#  'IN020_AE',
#  'IN021_AE',
#  'IN022_AE',
#  'IN023_AE',
#  'IN024_AE',
#  'IN025_AE',
#  'IN026_AE',
#  'IN027_AE',
#  'IN028_AE',
#  'IN029_AE',
#  'IN030_AE',
#  'IN031_AE',
#  'IN032_AE',
#  'IN033_AE',
#  'IN034_AE',
#  'IN035_AE',
#  'IN036_AE',
#  'IN037_AE',
#  'IN038_AE',
#  'IN039_AE',
#  'IN040_AE',
#  'IN041_AE',
#  'IN042_AE',
#  'IN043_AE',
#  'IN044_AE',
#  'IN045_AE',
#  'IN046_AE',
#  'IN047_AE',
#  'IN048_AE',
#  'IN049_AE',
#  'IN050_AE',
#  'IN051_AE',
#  'IN052_AE',
#  'IN053_AE',
#  'IN054_AE',
#  'IN055_AE',
#  'IN056_AE',
#  'IN057_AE',
#  'IN058_AE',
#  'IN059_AE',
#  'IN060_AE',
#  'IN071_AE',
#  'IN072_AE',
#  'IN073_AE',
#  'IN074_AE',
#  'IN075_AE',
#  'IN076_AE',
#  'IN077_AE',
#  'IN079_AE',
#  'IN080_AE',
#  'IN082_AE',
#  'IN083_AE',
#  'IN084_AE',
#  'IN085_AE',
#  'IN101_AE',
#  'IN102_AE',
#  'IN001_RS',
#  'IN002_RS',
#  'IN003_RS',
#  'IN004_RS',
#  'IN005_RS',
#  'IN006_RS',
#  'IN007_RS',
#  'IN008_RS',
#  'IN010_RS',
#  'IN011_RS',
#  'IN014_RS',
#  'IN015_RS',
#  'IN016_RS',
#  'IN017_RS',
#  'IN018_RS',
#  'IN019_RS',
#  'IN021_RS',
#  'IN022_RS',
#  'IN023_RS',
#  'IN024_RS',
#  'IN025_RS',
#  'IN026_RS',
#  'IN027_RS',
#  'IN028_RS',
#  'IN029_RS',
#  'IN030_RS',
#  'IN031_RS',
#  'IN032_RS',
#  'IN033_RS',
#  'IN034_RS',
#  'IN035_RS',
#  'IN036_RS',
#  'IN037_RS',
#  'IN038_RS',
#  'IN039_RS',
#  'IN040_RS',
#  'IN041_RS',
#  'IN042_RS',
#  'IN043_RS',
#  'IN044_RS',
#  'IN045_RS',
#  'IN046_RS',
#  'IN047_RS',
#  'IN048_RS',
#  'IN051_RS',
#  'IN052_RS',
#  'IN053_RS',
#  'IN054_RS']

# %%
# Atribuir o nome limpo das colunas que estão no dataframe "colunas" ao dataframe "df"
df_snis.columns = colunas

# Renomear os headers de todas as colunas para minúsculo
df_snis.columns = df_snis.columns.str.lower()

# Renomear os headers das colunas iniciais
df_snis = df_snis.rename(columns={"código do ibge": "cd_mun7", "código do município": "cd_mun6", "município":"nm_mun", "estado":"uf", "ano de referência":"ano_ref", 'serviços':'servicos', 'natureza jurídica':'nat_jur'})

# Exibir os registros iniciais
df_snis.head()
# Out:
#    cd_mun7 cd_mun6          nm_mun  uf ano_ref  \
# 0  3300100  330010  Angra dos Reis  RJ    2021
# 1  3300100  330010  Angra dos Reis  RJ    2020
# 2  3300100  330010  Angra dos Reis  RJ    2019
# 3      NaN  330010  Angra dos Reis  RJ    2018
# 4      NaN  330010  Angra dos Reis  RJ    2017
#
#                                          prestadores  \
# 0  [33045500] Companhia Estadual de Águas e Esgot...
# 1  [33045500] Companhia Estadual de Águas e Esgot...
# 2  [33045500] Companhia Estadual de Águas e Esgot...
# 3  [33001011] Serviço Autônomo de Água e Esgoto d...
# 4  [33001011] Serviço Autônomo de Água e Esgoto d...
#
#                               servicos  \
# 0  Água e Esgoto | Água | Res. Sólidos
# 1  Água e Esgoto | Água | Res. Sólidos
# 2  Água e Esgoto | Água | Res. Sólidos
# 3  Água e Esgoto | Água | Res. Sólidos
# 4  Água e Esgoto | Água | Res. Sólidos
#
#                                              nat_jur      g06a      g06b  ...  \
# 0  Autarquia | Sociedade de economia mista com ad...  202458.0  202458.0  ...
# 1  Autarquia | Sociedade de economia mista com ad...  199446.0  199446.0  ...
# 2  Autarquia | Sociedade de economia mista com ad...  196306.0  196306.0  ...
# 3                                                NaN  193052.0  193052.0  ...
# 4                                                NaN  187477.0  187477.0  ...
#
#    in043_rs  in044_rs  in045_rs  in046_rs  in047_rs  in048_rs  in051_rs  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN      0.88       NaN     40.42       NaN      0.25
# 2       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4       NaN       NaN      0.93     30.98     40.42       NaN      0.27
#
#    in052_rs in053_rs in054_rs
# 0       NaN      NaN    27.65
# 1     11.55      NaN     0.85
# 2       NaN      NaN     0.96
# 3       NaN      NaN    82.47
# 4     11.55    11.91    31.31
#
# [5 rows x 658 columns]

# %% [markdown]
# ## Abaixo vamos estudar a estrutura e o modelo de dados do nosso DataFrame para conhecê-lo um pouco melhor

# %%
# Exibindo as informações do dataframe
df_snis.info()

# Aqui temos informações sobre a quantidade de linhas e colunas e os tipos de dados que existem em nosso dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 461 entries, 0 to 460
# Columns: 658 entries, cd_mun7 to in054_rs
# dtypes: float64(483), int64(2), object(173)
# memory usage: 2.3+ MB

# %%
# Exibir os tipos de dados como uma lista em que apareça o header da coluna e o tipo de dado

# Obtenha os headers de coluna e dtypes
headers = df_snis.columns
dtypes = df_snis.dtypes

# Crie um laço for para iterar sobre os headers de coluna
for header in headers:
    # Imprima o header de coluna e o dtype
    print(f"{header} - {dtypes[header]}")
# Out:
# cd_mun7 - object
# cd_mun6 - object
# nm_mun - object
# uf - object
# ano_ref - object
# prestadores - object
# servicos - object
# nat_jur - object
# g06a - float64
# g06b - float64
# g12a - float64
# g12b - float64
# ge008 - float64
# ge009 - float64
# ge010 - float64
# ge011 - float64
# pop_tot - int64
# pop_urb - int64
# ge201 - object
# ge202 - object
# ag001 - float64
# ag002 - float64
# ag003 - float64
# ag004 - float64
# ag005 - float64
# ag006 - float64
# ag007 - float64
# ag008 - float64
# ag010 - float64
# ag011 - float64
# ag012 - float64
# ag013 - float64
# ag014 - float64
# ag015 - float64
# ag017 - float64
# ag018 - float64
# ag019 - float64
# ag020 - float64
# ag021 - float64
# ag022 - float64
# ag024 - float64
# ag026 - float64
# ag027 - float64
# ag028 - float64
# es001 - float64
# es002 - float64
# es003 - float64
# es004 - float64
# es005 - float64
# es006 - float64
# es007 - float64
# es008 - float64
# es009 - float64
# es012 - float64
# es013 - float64
# es014 - float64
# es015 - float64
# es026 - float64
# es028 - float64
# fn001 - float64
# fn002 - float64
# fn003 - float64
# fn004 - float64
# fn005 - float64
# fn006 - float64
# fn007 - float64
# fn008 - float64
# fn010 - float64
# fn011 - float64
# fn013 - float64
# fn014 - float64
# fn015 - float64
# fn016 - float64
# fn017 - float64
# fn018 - float64
# fn019 - float64
# fn020 - float64
# fn021 - float64
# fn022 - float64
# fn023 - float64
# fn024 - float64
# fn025 - float64
# fn026 - float64
# fn027 - float64
# fn028 - float64
# fn030 - float64
# fn031 - float64
# fn032 - float64
# fn033 - float64
# fn034 - float64
# fn035 - float64
# fn036 - float64
# fn037 - float64
# fn038 - float64
# fn039 - float64
# fn041 - float64
# fn042 - float64
# fn043 - float64
# fn044 - float64
# fn045 - float64
# fn046 - float64
# fn047 - float64
# fn048 - float64
# fn051 - float64
# fn052 - float64
# fn053 - float64
# fn054 - float64
# fn055 - float64
# fn056 - float64
# fn057 - float64
# fn058 - float64
# qd001 - object
# qd002 - float64
# qd003 - float64
# qd004 - float64
# qd006 - float64
# qd007 - float64
# qd008 - float64
# qd009 - float64
# qd011 - float64
# qd012 - float64
# qd015 - float64
# qd016 - float64
# qd017 - float64
# qd019 - float64
# qd020 - float64
# qd021 - float64
# qd022 - float64
# qd023 - float64
# qd024 - float64
# qd025 - float64
# qd026 - float64
# qd027 - float64
# qd028 - float64
# qd029 - float64
# ca001 - float64
# ca002 - float64
# ca003 - float64
# ca004 - object
# ca005 - object
# ca006 - float64
# ca007 - float64
# ca008 - object
# ca009 - object
# cc010 - object
# cc011 - float64
# cc012 - float64
# cc013 - float64
# cc014 - float64
# cc015 - float64
# cc016 - float64
# cc017 - object
# cc018 - object
# cc019 - object
# cc020 - object
# co001 - float64
# co002 - float64
# co003 - float64
# co004 - float64
# co008 - object
# co012 - float64
# co013 - float64
# co014 - float64
# co019 - object
# co020 - object
# co021 - object
# co022 - float64
# co050 - float64
# co051 - float64
# co052 - float64
# co053 - float64
# co054 - float64
# co055 - float64
# co056 - float64
# co057 - float64
# co058 - float64
# co059 - float64
# co060 - float64
# co061 - float64
# co062 - float64
# co063 - float64
# co064 - float64
# co065 - float64
# co066 - float64
# co067 - float64
# co068 - float64
# co069 - float64
# co070 - float64
# co071 - float64
# co072 - float64
# co073 - float64
# co074 - float64
# co075 - float64
# co076 - float64
# co077 - float64
# co078 - float64
# co079 - float64
# co080 - float64
# co081 - float64
# co082 - float64
# co083 - float64
# co084 - float64
# co085 - float64
# co086 - float64
# co087 - float64
# co088 - float64
# co089 - float64
# co090 - float64
# co091 - float64
# co092 - float64
# co093 - float64
# co094 - float64
# co095 - float64
# co096 - float64
# co097 - float64
# co098 - float64
# co099 - float64
# co100 - float64
# co101 - float64
# co102 - float64
# co103 - float64
# co104 - float64
# co105 - float64
# co106 - float64
# co107 - float64
# co108 - float64
# co109 - float64
# co110 - float64
# co111 - float64
# co112 - float64
# co113 - float64
# co114 - float64
# co115 - float64
# co116 - float64
# co117 - float64
# co118 - float64
# co119 - float64
# co120 - float64
# co121 - float64
# co122 - float64
# co123 - float64
# co124 - float64
# co125 - float64
# co126 - float64
# co127 - float64
# co128 - float64
# co129 - float64
# co130 - float64
# co131 - object
# co133 - float64
# co134 - float64
# co135 - float64
# co136 - float64
# co137 - float64
# co138 - float64
# co139 - float64
# co140 - float64
# co141 - float64
# co142 - float64
# co143 - float64
# co144 - float64
# co145 - float64
# co146 - float64
# co147 - float64
# co148 - object
# co149 - object
# co150 - float64
# co151 - object
# co152 - float64
# co154 - object
# co155 - float64
# co156 - float64
# co157 - float64
# co158 - float64
# co159 - float64
# co160 - float64
# co161 - object
# co162 - float64
# co163 - object
# co164 - float64
# co165 - float64
# co170 - float64
# co171 - float64
# co172 - float64
# co173 - float64
# co174 - float64
# co175 - float64
# cp001 - object
# cp002 - object
# cp003 - object
# cp004 - object
# cs001 - object
# cs002 - float64
# cs009 - float64
# cs010 - float64
# cs011 - float64
# cs012 - float64
# cs013 - float64
# cs014 - float64
# cs022 - float64
# cs023 - float64
# cs024 - float64
# cs025 - float64
# cs026 - float64
# cs027 - object
# cs028 - object
# cs029 - float64
# cs030 - object
# cs031 - object
# cs032 - object
# cs033 - float64
# cs034 - object
# cs035 - object
# cs036 - object
# cs037 - float64
# cs038 - object
# cs039 - float64
# cs040 - float64
# cs041 - float64
# cs042 - object
# cs043 - object
# cs044 - object
# cs045 - object
# cs046 - object
# cs047 - object
# cs048 - float64
# cs049 - object
# cs050 - float64
# cs053 - object
# cs054 - float64
# cs055 - object
# cs056 - float64
# cs057 - object
# cs058 - float64
# cs059 - object
# cs060 - float64
# fn201 - object
# fn202 - object
# fn203 - object
# fn204 - float64
# fn205 - object
# fn206 - float64
# fn207 - float64
# fn208 - float64
# fn209 - float64
# fn210 - float64
# fn211 - float64
# fn212 - float64
# fn213 - float64
# fn214 - float64
# fn215 - float64
# fn216 - float64
# fn217 - float64
# fn218 - float64
# fn219 - float64
# fn220 - float64
# fn221 - float64
# fn222 - float64
# fn223 - float64
# fn224 - object
# fn225 - float64
# fn226 - object
# fn227 - object
# os001 - object
# os003 - object
# os004 - object
# os005 - object
# os006 - object
# os007 - object
# os008 - object
# os009 - object
# os010 - object
# os011 - object
# os012 - object
# os014 - object
# os015 - object
# os016 - object
# os017 - object
# os018 - object
# os019 - object
# os020 - object
# os021 - object
# os022 - object
# os023 - object
# os025 - object
# os026 - object
# os027 - object
# os028 - object
# os029 - object
# os030 - object
# os031 - object
# os032 - object
# os033 - object
# os040 - object
# os041 - object
# os042 - object
# os043 - object
# os044 - object
# os045 - object
# os046 - object
# os047 - object
# os048 - object
# os049 - object
# os050 - object
# os051 - object
# os052 - object
# os053 - object
# po001 - object
# po002 - object
# po004 - object
# po005 - object
# po006 - object
# po007 - object
# po008 - object
# po009 - object
# po010 - object
# po011 - object
# po012 - object
# po013 - object
# po014 - object
# po015 - object
# po016 - object
# po017 - object
# po018 - object
# po019 - object
# po020 - object
# po021 - object
# po022 - object
# po023 - object
# po024 - object
# po025 - object
# po026 - object
# po027 - float64
# po028 - object
# po029 - object
# po031 - object
# po033 - object
# po034 - object
# po035 - object
# po036 - object
# po037 - object
# po038 - object
# po039 - object
# po040 - object
# po041 - object
# po042 - object
# po043 - object
# po044 - float64
# po045 - object
# po046 - object
# po047 - object
# po048 - object
# po049 - object
# po050 - object
# po051 - float64
# rs003 - object
# rs004 - object
# rs008 - float64
# rs009 - float64
# rs020 - object
# rs021 - float64
# rs022 - float64
# rs023 - float64
# rs024 - float64
# rs025 - float64
# rs026 - object
# rs027 - object
# rs028 - float64
# rs030 - object
# rs031 - object
# rs034 - float64
# rs036 - object
# rs038 - object
# rs039 - float64
# rs040 - object
# rs041 - float64
# rs042 - object
# rs043 - float64
# rs044 - float64
# rs045 - object
# rs046 - object
# tb001 - float64
# tb002 - float64
# tb003 - float64
# tb004 - float64
# tb005 - float64
# tb006 - float64
# tb007 - float64
# tb008 - float64
# tb009 - float64
# tb010 - float64
# tb011 - float64
# tb012 - float64
# tb013 - float64
# tb014 - float64
# tb015 - float64
# tb016 - object
# tb017 - float64
# tb018 - float64
# tb019 - float64
# tb020 - float64
# tb021 - float64
# tb022 - float64
# tb023 - object
# tb024 - object
# tb025 - object
# tb026 - object
# tb027 - object
# tb028 - object
# tb029 - float64
# tb030 - float64
# tb031 - float64
# tb032 - float64
# tb033 - float64
# tb034 - float64
# tb035 - float64
# va001 - float64
# va002 - float64
# va003 - float64
# va004 - float64
# va010 - float64
# va011 - float64
# va012 - float64
# va016 - object
# va020 - float64
# va021 - float64
# va030 - float64
# va031 - float64
# va032 - float64
# va033 - float64
# va034 - float64
# va035 - float64
# va036 - float64
# va038 - float64
# va039 - float64
# in001_ae - float64
# in002_ae - float64
# in003_ae - float64
# in004_ae - float64
# in005_ae - float64
# in006_ae - float64
# in007_ae - float64
# in008_ae - float64
# in009_ae - float64
# in010_ae - float64
# in011_ae - float64
# in012_ae - float64
# in013_ae - float64
# in014_ae - float64
# in015_ae - float64
# in016_ae - float64
# in017_ae - float64
# in018_ae - float64
# in019_ae - float64
# in020_ae - float64
# in021_ae - float64
# in022_ae - float64
# in023_ae - float64
# in024_ae - float64
# in025_ae - float64
# in026_ae - float64
# in027_ae - float64
# in028_ae - float64
# in029_ae - float64
# in030_ae - float64
# in031_ae - float64
# in032_ae - float64
# in033_ae - float64
# in034_ae - float64
# in035_ae - float64
# in036_ae - float64
# in037_ae - float64
# in038_ae - float64
# in039_ae - float64
# in040_ae - float64
# in041_ae - float64
# in042_ae - float64
# in043_ae - float64
# in044_ae - float64
# in045_ae - float64
# in046_ae - float64
# in047_ae - float64
# in048_ae - float64
# in049_ae - float64
# in050_ae - float64
# in051_ae - float64
# in052_ae - float64
# in053_ae - float64
# in054_ae - float64
# in055_ae - float64
# in056_ae - float64
# in057_ae - float64
# in058_ae - float64
# in059_ae - float64
# in060_ae - float64
# in071_ae - float64
# in072_ae - float64
# in073_ae - float64
# in074_ae - float64
# in075_ae - float64
# in076_ae - float64
# in077_ae - float64
# in079_ae - float64
# in080_ae - float64
# in082_ae - float64
# in083_ae - float64
# in084_ae - float64
# in085_ae - float64
# in101_ae - float64
# in102_ae - float64
# in001_rs - float64
# in002_rs - float64
# in003_rs - float64
# in004_rs - float64
# in005_rs - float64
# in006_rs - float64
# in007_rs - float64
# in008_rs - float64
# in010_rs - float64
# in011_rs - float64
# in014_rs - float64
# in015_rs - float64
# in016_rs - float64
# in017_rs - float64
# in018_rs - float64
# in019_rs - float64
# in021_rs - float64
# in022_rs - float64
# in023_rs - float64
# in024_rs - float64
# in025_rs - float64
# in026_rs - float64
# in027_rs - float64
# in028_rs - float64
# in029_rs - float64
# in030_rs - float64
# in031_rs - float64
# in032_rs - float64
# in033_rs - float64
# in034_rs - float64
# in035_rs - float64
# in036_rs - float64
# in037_rs - float64
# in038_rs - float64
# in039_rs - float64
# in040_rs - float64
# in041_rs - float64
# in042_rs - float64
# in043_rs - float64
# in044_rs - float64
# in045_rs - float64
# in046_rs - float64
# in047_rs - float64
# in048_rs - float64
# in051_rs - float64
# in052_rs - float64
# in053_rs - float64
# in054_rs - float64

# %% [markdown]
# ##  Filtrar o dataframe "df_snis" para formar um novo dataframe "df_snis_2021"

# %%
# Selecionar apenas as colunas de abastecimento que decidi trabalhar
df_filtrado = df_snis[['cd_mun7', 'cd_mun6', 'nm_mun', 'uf', 'ano_ref', 'prestadores', 'servicos', 'nat_jur',
                'ge009','ge011','es002','es004','es005','es006','es007','es008','es009','in015_ae','in016_ae','in021_ae','in046_ae',
                'ge008', 'ge010','ag003','ag004','ag005','ag021','ag022','ag008','ag010','ag011','ag012','in003_ae','in005_ae','in028_ae','in049_ae']]

# filtrando para 2021
df_snis_2021 = df_filtrado[df_filtrado['ano_ref'] == '2021']

# Alterando o index dos novos dataframes filtrados porque eles herdaram o index do dataframe "df_snis_abastecimento" e "df_snis_esgotamento"
df_snis_2021 = df_snis_2021.reset_index(drop=True)

#Exibir o dataframe
df_snis_2021
# Out:
#     cd_mun7 cd_mun6              nm_mun  uf ano_ref  \
# 0   3300100  330010      Angra dos Reis  RJ    2021
# 1   3300159  330015             Aperibé  RJ    2021
# 2   3300209  330020            Araruama  RJ    2021
# 3   3300225  330022               Areal  RJ    2021
# 4   3300233  330023  Armação dos Búzios  RJ    2021
# ..      ...     ...                 ...  ..     ...
# 87  3306008  330600           Três Rios  RJ    2021
# 88  3306107  330610             Valença  RJ    2021
# 89  3306156  330615           Varre-Sai  RJ    2021
# 90  3306206  330620           Vassouras  RJ    2021
# 91  3306305  330630       Volta Redonda  RJ    2021
#
#                                           prestadores  \
# 0   [33045500] Companhia Estadual de Águas e Esgot...
# 1   [33045500] Companhia Estadual de Águas e Esgot...
# 2   [33002011] Concessionária Águas de Juturnaíba ...
# 3                                                 NaN
# 4   [33007011] Prolagos S/A - Concessionária de Se...
# ..                                                ...
# 87  [33060011] Serviço Autônomo de Água e Esgoto d...
# 88  [33045500] Companhia Estadual de Águas e Esgot...
# 89  [33045500] Companhia Estadual de Águas e Esgot...
# 90  [33045500] Companhia Estadual de Águas e Esgot...
# 91  [33063011] Serviço Autônomo de Água e Esgoto d...
#
#                                          servicos  \
# 0             Água e Esgoto | Água | Res. Sólidos
# 1   Esgotos | Água | Água e Esgoto | Res. Sólidos
# 2                    Água e Esgoto | Res. Sólidos
# 3                                             NaN
# 4                    Água e Esgoto | Res. Sólidos
# ..                                            ...
# 87                   Água e Esgoto | Res. Sólidos
# 88                  Esgotos | Água | Res. Sólidos
# 89                            Água | Res. Sólidos
# 90                  Esgotos | Água | Res. Sólidos
# 91                   Água e Esgoto | Res. Sólidos
#
#                                               nat_jur  ge009  ge011  ...  \
# 0   Autarquia | Sociedade de economia mista com ad...    1.0   35.0  ...
# 1   Administração pública direta | Sociedade de ec...    1.0    3.0  ...
# 2      Empresa privada | Administração pública direta    1.0    1.0  ...
# 3                                                 NaN    NaN    NaN  ...
# 4      Empresa privada | Administração pública direta    1.0    0.0  ...
# ..                                                ...    ...    ...  ...
# 87           Autarquia | Administração pública direta    1.0    1.0  ...
# 88  Administração pública direta | Sociedade de ec...    1.0    5.0  ...
# 89  Sociedade de economia mista com administração ...    NaN    NaN  ...
# 90  Administração pública direta | Sociedade de ec...    1.0    1.0  ...
# 91           Autarquia | Administração pública direta    1.0    0.0  ...
#
#       ag021     ag022     ag008     ag010     ag011     ag012  in003_ae  \
# 0   54616.0   25473.0   4472.22  15075.45  16985.16      0.00      2.76
# 1    3578.0    3799.0    616.22    720.76    793.99      0.00      4.22
# 2   71225.0   66879.0   9641.86  15312.87  10581.55  21602.74     11.82
# 3       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4   18628.0   23775.0   3417.00   3417.00   4242.00   6786.00      2.91
# ..      ...       ...       ...       ...       ...       ...       ...
# 87  42821.0   27076.0   4698.00   9013.00   5306.00  10399.34      3.50
# 88  19105.0   19694.0   4302.72   5449.77   4350.79      0.00      5.82
# 89   1094.0    1060.0    164.64    200.15    254.80      0.00     11.62
# 90  11008.0   12285.0   1673.75   2042.68   2754.17      0.00      5.44
# 91  90548.0  117746.0  16935.17  18517.81  20977.73  36753.56      2.84
#
#     in005_ae  in028_ae  in049_ae
# 0       2.83     78.64     30.20
# 1       5.00     44.05     60.01
# 2      19.73     52.48     24.05
# 3        NaN       NaN       NaN
# 4      16.49     92.24     25.70
# ..       ...       ...       ...
# 87      3.80     51.02     13.33
# 88      4.45     37.72     52.75
# 89      5.08     61.69     51.54
# 90      5.25     69.60     48.38
# 91      3.00     57.08     49.62
#
# [92 rows x 36 columns]

# %% [markdown]
# # Processamento
#
# ## Estatística Descritiva

# %%
# Calcular a estatística descritiva básica do dataset para cada coluna numérica
df_snis_2021.describe()
# Out:
#            ge009      ge011          es002        es004          es005  \
# count  76.000000  76.000000      69.000000    69.000000      76.000000
# mean    0.986842   2.776316   32766.260870   297.737246    9382.600789
# std     0.114708   5.395303  106369.522527   863.535445   46624.025374
# min     0.000000   0.000000     315.000000     0.970000       0.000000
# 25%     1.000000   0.000000    3686.000000    33.200000     445.140000
# 50%     1.000000   1.000000   10000.000000    65.000000    1828.405000
# 75%     1.000000   3.000000   32800.000000   281.290000    4111.587500
# max     1.000000  35.000000  880189.000000  7009.580000  406681.070000
#
#                es006          es007         es008         es009    in015_ae  \
# count      76.000000      76.000000  4.800000e+01  6.900000e+01   76.000000
# mean     6618.056711    7679.223026  7.643754e+04  3.915219e+04   58.917895
# std     39833.206268   48989.904382  2.886769e+05  1.414976e+05   35.637865
# min         0.000000       0.000000  3.200000e+02  3.200000e+02    0.000000
# 25%         0.000000       0.000000  5.109500e+03  3.857000e+03   28.790000
# 50%       123.220000       0.000000  1.819250e+04  1.150000e+04   64.920000
# 75%      2103.905000     427.720000  5.643200e+04  3.853100e+04  100.000000
# max    346468.380000  426632.080000  2.014093e+06  1.176971e+06  100.000000
#
#        ...         ag021         ag022          ag008         ag010  \
# count  ...  9.000000e+01  8.500000e+01      90.000000  9.000000e+01
# mean   ...  4.281930e+04  4.488498e+04    6685.509667  2.854971e+04
# std    ...  1.515047e+05  1.757884e+05   35104.123666  1.445281e+05
# min    ...  1.094000e+03  0.000000e+00       0.000000  1.844300e+02
# 25%    ...  4.800750e+03  3.458000e+03     458.245000  7.506100e+02
# 50%    ...  1.107200e+04  8.646000e+03    1243.290000  2.087100e+03
# 75%    ...  3.655325e+04  2.916600e+04    3684.800000  8.797068e+03
# max    ...  1.418384e+06  1.607079e+06  332614.590000  1.285170e+06
#
#               ag011         ag012   in003_ae   in005_ae    in028_ae   in049_ae
# count  9.000000e+01  9.000000e+01  88.000000  86.000000   90.000000  90.000000
# mean   2.716431e+04  2.321981e+04   6.523864   5.853605   61.832889  41.820222
# std    1.436112e+05  1.466285e+05   4.292184   3.036881   26.303163  19.044687
# min    0.000000e+00  0.000000e+00   0.210000   0.460000    0.000000   0.560000
# 25%    9.315025e+02  0.000000e+00   3.875000   5.032500   44.337500  27.297500
# 50%    2.180520e+03  0.000000e+00   5.715000   5.390000   61.125000  41.705000
# 75%    7.840945e+03  1.947700e+03   7.787500   5.980000   80.657500  56.417500
# max    1.289567e+06  1.368915e+06  29.020000  19.730000  114.100000  86.110000
#
# [8 rows x 28 columns]

# %%
def calcula_media_metrica_ano(metrica: str, ano: int, df: pd.DataFrame) -> float:
    """
    Função para retornar a média de uma métrica em um determinado ano
    metrica: nome da métrica
    ano: ano da métrica
    df: DataFrame a ser analisado
    """
    return df[df['ano_ref'] == str(ano)][metrica.lower()].mean(skipna=True)

def calcula_total_metrica_ano(metrica: str, ano: int, df: pd.DataFrame) -> float:
    """
    Função para retornar o total de uma métrica em um determinado ano
    metrica: nome da métrica
    ano: ano da métrica
    df: DataFrame a ser analisado
    """
    return df[df['ano_ref'] == str(ano)][metrica.lower()].sum(skipna=True)

# %%
# dicionário com os nomes e os indicadores
dicionario_indicadores_total = dict()

# Cálculo de fato dos indicadores
# GE008 - Quantidade de sedes municipais atendidas com abastecimento de água
ge008 = calcula_total_metrica_ano('GE008',2021,df_snis)
dicionario_indicadores_total['ge008'] = ge008

# GE009 - Quantidade de sedes municipais atendidas com esgotamento sanitário
ge009 = calcula_total_metrica_ano('GE009',2021,df_snis)
dicionario_indicadores_total['ge009'] = ge009

# GE010 - Quantidade de localidades (excluídas as sedes) atendidas com abastecimento de água
ge010 = calcula_total_metrica_ano('GE010',2021,df_snis)
dicionario_indicadores_total['ge010'] = ge010

# GE011 - Quantidade de localidades (excluídas as sedes) atendidas com esgotamento sanitário
ge011 = calcula_total_metrica_ano('GE011',2021,df_snis)
dicionario_indicadores_total['ge010'] = ge010

# AG003 - Quantidade de economias ativas de água 
ag003 = calcula_total_metrica_ano('AG003',2021,df_snis)
dicionario_indicadores_total['ag003'] = ag003

# AG004 - Quantidade de ligações ativas de Água Micromedidas 
ag004 = calcula_total_metrica_ano('AG004',2021,df_snis)
dicionario_indicadores_total['ag004'] = ag004

# AG005 - Extensão da Rede de Água (km)
ag005 = calcula_total_metrica_ano('AG005',2021,df_snis)
dicionario_indicadores_total['ag005'] = ag005

# AG008 - Volume de água micromedido
ag008 = calcula_total_metrica_ano('AG008',2021,df_snis)
dicionario_indicadores_total['ag008'] = ag008

# AG010 - Volume de água consumido
ag010 = calcula_total_metrica_ano('AG010',2021,df_snis)
dicionario_indicadores_total['ag010'] = ag010

# AG011 - Volume de água faturado
ag011 = calcula_total_metrica_ano('AG011',2021,df_snis)
dicionario_indicadores_total['ag011'] = ag011

# AG012 - Volume de água Macromedido
ag012 = calcula_total_metrica_ano('AG012',2021,df_snis)
dicionario_indicadores_total['ag012'] = ag012

# AG021 - Quantidade de Ligações Totais de Água
ag021 = calcula_total_metrica_ano('AG021',2021,df_snis)
dicionario_indicadores_total['ag021'] = ag021

# AG022 - Quantidade de economias residenciais ativas de água Micromedidas
ag022 = calcula_total_metrica_ano('AG022',2021,df_snis)
dicionario_indicadores_total['ag022'] = ag022

# ES002 - Quantidade de ligações ativas de esgoto
es002 = calcula_total_metrica_ano('ES002',2021,df_snis)
dicionario_indicadores_total['es002'] = es002

# ES004 - Extensão da rede de esgotos
es004 = calcula_total_metrica_ano('ES004',2021,df_snis)
dicionario_indicadores_total['es004'] = es004

# ES005 - Volume de esgotos coletado
es005 = calcula_total_metrica_ano('ES005',2021,df_snis)
dicionario_indicadores_total['es005'] = es005

# ES006 - Volume de esgoto tratado
es006 = calcula_total_metrica_ano('ES006',2021,df_snis)
dicionario_indicadores_total['es006'] = es006

# AG007 - Volume de esgotos faturado
es007 = calcula_total_metrica_ano('ES007',2021,df_snis)
dicionario_indicadores_total['es007'] = es007

# ES008 - Quantidade de economias residenciais ativas de esgoto
es008 = calcula_total_metrica_ano('ES008',2021,df_snis)
dicionario_indicadores_total['es008'] = es008

# ES009 - Quantidade de ligações totais de esgoto
es009 = calcula_total_metrica_ano('ES009',2021,df_snis)
dicionario_indicadores_total['es009'] = es009

'''-------------------------------------------------------------------------------------------------------------'''

# * médias
# São calculadas usando do dataframe completo "df" e não o dataframe filtrado

# dicionário com os nomes e os indicadores
dicionario_indicadores_medias = dict()

# Cálculo de fato dos indicadores
# 'IN003_AE': Despesa total com os serviços por M³ faturado - (R$/M³)
# 'IN003_AE' = (FN017 / AG011 + ES007) * 1/1000
fn017 = calcula_media_metrica_ano('FN017', 2021, df_snis)
ag011 = calcula_media_metrica_ano('AG011', 2021, df_snis)
es007 = calcula_media_metrica_ano('ES007', 2021, df_snis)
in003_ae = (fn017 / ag011 + es007) * 1/1000
dicionario_indicadores_medias['in003_ae'] = in003_ae

# 'IN005_AE': Tarifa média de água - (R$/M³)
# 'IN005_AE' = (FN002 / AG011 - AG017 - AG019) * 1/1000
fn002 = calcula_media_metrica_ano('fn002', 2021, df_snis)
ag011 = calcula_media_metrica_ano('AG011', 2021, df_snis)
ag017 = calcula_media_metrica_ano('AG017', 2021, df_snis)
ag019 = calcula_media_metrica_ano('AG019', 2021, df_snis)
in005_ae = (fn002 / ag011 - ag017 - ag019) * 1/1000
dicionario_indicadores_medias['in005_ae'] = in005_ae

# 'IN049_AE': Índice de Perdas na Distribuição
# 'IN049_AE' = (AG006 + AG018 - AG010 - AG024 / AG006 + AG018 - AG024) * 100
ag006 = calcula_media_metrica_ano('ag006', 2021, df_snis)
ag010 = calcula_media_metrica_ano('ag010', 2021, df_snis)
ag018 = calcula_media_metrica_ano('ag018', 2021, df_snis)
ag024 = calcula_media_metrica_ano('ag024', 2021, df_snis)
in049_ae = (ag006 + ag018 - ag010 - ag024 / ag006 + ag018 - ag024) * 100
dicionario_indicadores_medias['in049_ae'] = in049_ae


# 'IN015_AE': Índice de Perdas na Distribuição (%)
# 'IN015_AE' = (ES005 / AG010 - AG019) * 100
es005 = calcula_media_metrica_ano('ES005', 2021, df_snis)
ag010 = calcula_media_metrica_ano('AG010',2021, df_snis)
ag019 = calcula_media_metrica_ano('AG019', 2021, df_snis)
in015_ae = (es005 / ag010 - ag019) * 100
dicionario_indicadores_medias['in015_ae'] = in015_ae

# 'IN016_AE': Índice de Perdas na Distribuição (%)
# 'IN016_AE' = (ES006 + ES014 + ES015 / ES005 + ES013) * 100
es005 = calcula_media_metrica_ano('ES005', 2021, df_snis)
es006 = calcula_media_metrica_ano('ES006', 2021, df_snis)
es013 = calcula_media_metrica_ano('ES013', 2021, df_snis)
es014 = calcula_media_metrica_ano('ES014', 2021, df_snis)
es015 = calcula_media_metrica_ano('ES015', 2021, df_snis)
in016_ae = (es006 + es014 + es015 / es005 + es013) * 100
dicionario_indicadores_medias['in016_ae'] = in016_ae

# 'IN021_AE': Extensão da rede de esgoto por ligação (m/lig)
# 'IN021_AE' = 
es004 = calcula_media_metrica_ano('ES004', 2021, df_snis)
es009 = calcula_media_metrica_ano('ES009', 2021, df_snis)
in021_ae = (es004 / es009) * 1000
dicionario_indicadores_medias['in021_ae'] = in021_ae

# 'IN046_AE': Índice de esgoto tratado referido a água consumida
# 'IN046_AE' = 
es006 = calcula_media_metrica_ano('ES006', 2021, df_snis)
es015 = calcula_media_metrica_ano('ES015', 2021, df_snis)
ag010 = calcula_media_metrica_ano('AG010', 2021, df_snis)
ag019 = calcula_media_metrica_ano('AG019', 2021, df_snis)
in046_ae = (es006 + es015 / ag010 - ag019) * 100
dicionario_indicadores_medias['in046_ae'] = in046_ae

# %%
linha_valor_erj = pd.DataFrame([
                                {'cd_mun7' : 333, 'cd_mun6': 333000, 'nm_mun': 'Valor para ERJ', 'uf':'RJ','ano_ref': '2021', 'prestadores': 'não se aplica', 'servicos': 'não se aplica', 'nat_jur':'nat_jur'}
                                |dicionario_indicadores_medias
                                |dicionario_indicadores_total
                                ])
linha_valor_erj.index = [92]

# inserindo linha com total e médias, nesta ordem
df_snis_2021 = pd.concat([df_snis_2021, linha_valor_erj])

df_snis_2021
# Out:
#     cd_mun7 cd_mun6              nm_mun  uf ano_ref  \
# 0   3300100  330010      Angra dos Reis  RJ    2021
# 1   3300159  330015             Aperibé  RJ    2021
# 2   3300209  330020            Araruama  RJ    2021
# 3   3300225  330022               Areal  RJ    2021
# 4   3300233  330023  Armação dos Búzios  RJ    2021
# ..      ...     ...                 ...  ..     ...
# 88  3306107  330610             Valença  RJ    2021
# 89  3306156  330615           Varre-Sai  RJ    2021
# 90  3306206  330620           Vassouras  RJ    2021
# 91  3306305  330630       Volta Redonda  RJ    2021
# 92      333  333000      Valor para ERJ  RJ    2021
#
#                                           prestadores  \
# 0   [33045500] Companhia Estadual de Águas e Esgot...
# 1   [33045500] Companhia Estadual de Águas e Esgot...
# 2   [33002011] Concessionária Águas de Juturnaíba ...
# 3                                                 NaN
# 4   [33007011] Prolagos S/A - Concessionária de Se...
# ..                                                ...
# 88  [33045500] Companhia Estadual de Águas e Esgot...
# 89  [33045500] Companhia Estadual de Águas e Esgot...
# 90  [33045500] Companhia Estadual de Águas e Esgot...
# 91  [33063011] Serviço Autônomo de Água e Esgoto d...
# 92                                      não se aplica
#
#                                          servicos  \
# 0             Água e Esgoto | Água | Res. Sólidos
# 1   Esgotos | Água | Água e Esgoto | Res. Sólidos
# 2                    Água e Esgoto | Res. Sólidos
# 3                                             NaN
# 4                    Água e Esgoto | Res. Sólidos
# ..                                            ...
# 88                  Esgotos | Água | Res. Sólidos
# 89                            Água | Res. Sólidos
# 90                  Esgotos | Água | Res. Sólidos
# 91                   Água e Esgoto | Res. Sólidos
# 92                                  não se aplica
#
#                                               nat_jur  ge009  ge011  ...  \
# 0   Autarquia | Sociedade de economia mista com ad...    1.0   35.0  ...
# 1   Administração pública direta | Sociedade de ec...    1.0    3.0  ...
# 2      Empresa privada | Administração pública direta    1.0    1.0  ...
# 3                                                 NaN    NaN    NaN  ...
# 4      Empresa privada | Administração pública direta    1.0    0.0  ...
# ..                                                ...    ...    ...  ...
# 88  Administração pública direta | Sociedade de ec...    1.0    5.0  ...
# 89  Sociedade de economia mista com administração ...    NaN    NaN  ...
# 90  Administração pública direta | Sociedade de ec...    1.0    1.0  ...
# 91           Autarquia | Administração pública direta    1.0    0.0  ...
# 92                                            nat_jur   75.0    NaN  ...
#
#         ag021      ag022      ag008       ag010       ag011       ag012  \
# 0     54616.0    25473.0    4472.22    15075.45    16985.16        0.00
# 1      3578.0     3799.0     616.22      720.76      793.99        0.00
# 2     71225.0    66879.0    9641.86    15312.87    10581.55    21602.74
# 3         NaN        NaN        NaN         NaN         NaN         NaN
# 4     18628.0    23775.0    3417.00     3417.00     4242.00     6786.00
# ..        ...        ...        ...         ...         ...         ...
# 88    19105.0    19694.0    4302.72     5449.77     4350.79        0.00
# 89     1094.0     1060.0     164.64      200.15      254.80        0.00
# 90    11008.0    12285.0    1673.75     2042.68     2754.17        0.00
# 91    90548.0   117746.0   16935.17    18517.81    20977.73    36753.56
# 92  3853737.0  3815223.0  601695.87  2569473.56  2444787.58  2089783.21
#
#      in003_ae  in005_ae  in028_ae      in049_ae
# 0    2.760000     2.830     78.64  3.020000e+01
# 1    4.220000     5.000     44.05  6.001000e+01
# 2   11.820000    19.730     52.48  2.405000e+01
# 3         NaN       NaN       NaN           NaN
# 4    2.910000    16.490     92.24  2.570000e+01
# ..        ...       ...       ...           ...
# 88   5.820000     4.450     37.72  5.275000e+01
# 89  11.620000     5.080     61.69  5.154000e+01
# 90   5.440000     5.250     69.60  4.838000e+01
# 91   2.840000     3.000     57.08  4.962000e+01
# 92  11.030739   -14.713       NaN  3.093923e+06
#
# [93 rows x 36 columns]

# %% [markdown]
# # Conexão e Importação para Banco de Dados
#
# ## Usando a biblioteca sqlalchemy para importar os DataFrames após a etapa de Data Cleaning

# %%
# CONEXÃO COM BANCO DE DADOS LOCAL

from sqlalchemy import create_engine

# Substitua os valores entre chaves {} pelos seus próprios dados
conexao  = 'postgresql://{}:{}@localhost:{}/{}'.format('postgres','MudarePreciso123','5432','gisdb') # SINTAXE: usuario:senha@localhost:porta/database

#Criar uma engine de conexão
engine = create_engine(conexao)

# Exibir a string de conexão
print(conexao )

df_snis.to_sql('df_snis', engine, schema='saneamento', if_exists='replace', index=True)
df_snis_2021.to_sql('df_snis_2021', engine, schema='saneamento', if_exists='replace', index=True)

# Fecha a conexão com o banco
engine.dispose()
# Out:
# postgresql://postgres:MudarePreciso123@localhost:5432/gisdb
